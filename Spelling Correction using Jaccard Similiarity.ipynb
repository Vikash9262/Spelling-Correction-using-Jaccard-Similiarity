# %%
a=set("Machine")
b=set("Mahine")

# %%
n = len(a&b)

# %%
n
# Out:
# 6

# %%
dict = ["receive","believe","friend","learning","machine","python","science","data","school","collage","project","analysis"]

# %%
def char_ngrams(word,n=2):
    word=word.lower()
    return [word[i:i+n] for i in range(len(word)-n+1)]

# %%
char_ngrams("university")
# Out:
# ['un', 'ni', 'iv', 've', 'er', 'rs', 'si', 'it', 'ty']

# %%
def jaccard_similarity(a,b):
    set1 = set(a)
    set2 = set(b)
    return len(set1&set2) / len(set1 | set2)

# %%
def correct_spelling(word,dictionary,n=2):
    word_ngrams = char_ngrams(word,n)
    best_match = None
    best_score = 0

    for correct_word in dictionary:
        correct_ngrams = char_ngrams(correct_word,n)
        score = jaccard_similarity(word_ngrams,correct_ngrams)

        if score>best_score:
            best_score = score
            best_match = correct_word
    return best_match,best_score

# %%
wrong_word = ["recieve","friend","leanning","machin","scince"]
for w in wrong_word:
    match,score = correct_spelling(w,dict)
    print(f"{w}----> {match}  (score  : {score:.2f})")
# Out:
# recieve----> receive  (score  : 0.33)
# friend----> friend  (score  : 1.00)
# leanning----> learning  (score  : 0.56)
# machin----> machine  (score  : 0.83)
# scince----> science  (score  : 0.57)

# %%
import re

# %%
def preprocessing(word):
    word = word.lower()
    word = re.sub(r"[^a-z]","",word)
    return word

# %%
preprocessing("company#5")
# Out:
# 'company'

# %%
def imporove_correction(word,dictionary,n=2):
    word_ngrams = char_ngrams(word,n)
    best_match = None
    best_score = 0

    for correct_word in dictionary:
        correct_clean = preprocessing(correct_word)
        correct_ngrams = char_ngrams(correct_word,n)
        score = jaccard_similarity(word_ngrams,correct_ngrams)

        if score>best_score:
            best_score = score
            best_match = correct_word
    return best_match,best_score

# %%
test_word = ["Recieve","Friend123","Machin?","Science"]
for word in test_word:
    match,score = imporove_correction(word,dict)
    print(f"{word}----> {match}  (score  : {score:.2f})")
# Out:
# Recieve----> receive  (score  : 0.33)
# Friend123----> friend  (score  : 0.62)
# Machin?----> machine  (score  : 0.71)
# Science----> science  (score  : 1.00)
